# %% [markdown]
# # Transfer learning results

# %% [markdown]
# ## One hot encoding

# %% [markdown]
# ![OneHotEncoding](data:image/png;base64,...)

# %% [markdown]
# ## Actin

# %% [markdown]
# ![Actin](data:image/png;base64,...)

# %% [markdown]
# ## Budneck

# %% [markdown]
# ![Budneck](data:image/png;base64,...)

# %% [markdown]
# ## Budtip

# %% [markdown]
# ![budtip](data:image/png;base64,...)

# %% [markdown]
# ## Cellperiphery

# %% [markdown]
# ![Cellperiphery](data:image/png;base64,...)

# %% [markdown]
# ## Cytoplasm

# %% [markdown]
# ![Cytoplasm](data:image/png;base64,...)

# %% [markdown]
# ## Peroxisome

# %% [markdown]
# {'test': 4516, 'train': 20894, 'val': 4368}

# %% [markdown]
# ![Peroxisome](data:image/png;base64,...)
